# %% [markdown]
# # Q3: Cohort Engagement Analysis
#
# **Objective:** Analyze engagement patterns across mortgage cohorts.
#
# **Sections:**
# 1. Data loading
# 2. Cohort construction
# 3. Engagement metrics
# 4. Visualizations
# 5. Key findings

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)

# %%
mortgages = pd.read_csv('../data/seeds/mortgages.csv')
applicants = pd.read_csv('../data/seeds/applicants.csv')
events     = pd.read_csv('../data/seeds/events.csv')
